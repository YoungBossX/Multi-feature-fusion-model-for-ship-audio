# %%
import sys, re, csv
from pathlib import Path
import pandas as pd
import numpy as np

# %%
COLUMNS = ["ID", "class ID", "Recording ID", "Ship Name",
           "Date & Time", "Duration(sec)", "Distances(m)"]
           
def clean_line(s):
    # 统一空白和连字符
    return (s.replace("\u00A0", " ")   # nbsp -> space
             .replace("\u2013", "-")  # en-dash –
             .replace("\u2014", "-")  # em-dash —
             .replace("\u2212", "-")  # minus sign −
             .strip())

def parse_file(path):
    rows, bad = [], 0
    with open(path, "r") as f:
        for line_num, raw in enumerate(f, 1):
            line = clean_line(raw)

            # 跳过空行
            if not line:
                continue

            # 使用逗号分割数据
            parts = [part.strip() for part in line.split(',')]
            
            # 提取各个字段
            id = parts[0].strip()
            class_id = parts[1].strip() 
            ship_name = parts[2].strip()
            date_part = parts[3].strip()
            time_part = parts[4].strip()
            duration = parts[5].strip()
            distances = parts[6].strip()
            
            # 合并日期和时间，格式化为 YYYYMMDD:HHMMSS
            date_time = f"{date_part}:{time_part}"
            
            # 这里假设 Recording ID 和 ID 相同，或者可以根据需要调整
            recording_id = id # 或者可以设置为其他值
            
            rows.append([id, class_id, recording_id, ship_name, date_time, duration, distances])
    
    return rows

# %%
in_path = Path(r"X:\数据集\DeepShip\annotation_original\tug-metafile")
out_path = in_path.with_suffix(".csv")
rows = parse_file(in_path)
with open(out_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(COLUMNS)
        writer.writerows(rows)
print(f"Saved: {out_path})")
# Out:
# Saved: X:\数据集\DeepShip\annotation_original\tug-metafile.csv)

# %%
# 1. 合并四个标注文件
annotation_original_dir = Path(r"X:\数据集\DeepShip\annotation_original")
data_dir = annotation_original_dir
files = {
    "cargo": data_dir / "cargo-metafile.csv",
    "passenger": data_dir / "passengership-metafile.csv",
    "tanker": data_dir / "tanker-metafile.csv",
    "tug": data_dir / "tug-metafile.csv",
}

dfs = []
for label, path in files.items():
    df = pd.read_csv(path)
    dfs.append(df)

merged = pd.concat(dfs, ignore_index=True)
merged["ID"] = merged["ID"].astype(int)

# 2. 添加 class_id
class_id = merged["class ID"].astype(int)
merged["class_id"] = np.select(
    [
        class_id.between(70, 79),  # Cargo
        class_id.between(60, 69),  # Passengership
        class_id.between(80, 89),  # Tanker
        class_id == 52,            # Tug
    ],
    [0, 1, 2, 3],
    default=-1
)

# 3. 构建 folder_name 映射
data_root = Path(r"X:\数据集\DeepShip\data_preprocessing\data")
class_dirs = {0: "Cargo", 1: "Passengership", 2: "Tanker", 3: "Tug"}

def parse_id(folder_name: str):
    parts = folder_name.rsplit("-", 1)
    if len(parts) != 2 or not parts[1].isdigit():
        return None
    return int(parts[1])

folder_map = {}
for cid, dirname in class_dirs.items():
    cls_dir = data_root / dirname
    if not cls_dir.exists():
        continue
    for sub in cls_dir.iterdir():
        if not sub.is_dir():
            continue
        sid = parse_id(sub.name)
        if sid is not None:
            folder_map[(cid, sid)] = sub.name

merged["folder_name"] = merged.apply(
    lambda row: folder_map.get(
        (int(row["class_id"]), int(row["ID"])),
        pd.NA
    ),
    axis=1,
)

# 4. 写回文件
merged.to_csv(r"X:\数据集\DeepShip\data_preprocessing\annotation\DeepShip.csv", index=False)

# %%
def bucket_distance(value):
    """
    输入: 原始字符串/数值，形如 '1583-1981' 或 '1600 – 1905' 等
    输出: (labels, distances)
         labels: ['near'|'mid'|'far'|...]
         distances: [float, float, ...]
    """
    # 1) 统一分隔符：用“非数字/小数点”的任意字符作为分割
    parts = re.split(r'[^0-9.]+', str(value).strip())
    distances, labels = [], []
    for p in parts:
        if not p:
            continue
        try:
            d = float(p)
        except ValueError:
            continue
        distances.append(d)
        if d < 300:
            labels.append("near")
        elif d <= 1000:
            labels.append("mid")
        else:
            labels.append("far")
    return labels, distances

def make_prompt(distance_str):
    labels, distances = bucket_distance(distance_str)

    # 解析失败：返回最安全句式
    if len(distances) == 0:
        return "Hydrophone recording of a marine vessel."

    # 只有一个值：直接用该档位
    if len(distances) == 1:
        return f"Hydrophone recording of a marine vessel at {labels[0]} range."

    # 取前两个时刻（你的标注基本就是两值）
    d0, d1 = distances[0], distances[1]
    l0, l1 = labels[0], labels[1]

    # 两次都在同一档位：判断是否“明显变远/变近/基本不变”
    if l0 == l1:
        rel = (d1 - d0) / max(abs(d0), 1e-6)
        if rel > 0.10:
            return f"Hydrophone recording of a marine vessel at {l0} range and getting farther."
        elif rel < -0.10:
            return f"Hydrophone recording of a marine vessel at {l0} range and getting closer."
        else:
            return f"Hydrophone recording of a marine vessel that remains at {l0} range."

    # 落在不同档位：用文字“then”表达顺序（不使用连字符）
    # 只拼接前两个标签，避免极端多段值导致过长
    return f"Hydrophone recording of a marine vessel at a {l0} range and then at {l1} range."

file_path = r"X:\数据集\DeepShip\data_preprocessing\annotation\DeepShip.csv"
df = pd.read_csv(file_path)
df["prompt_en"] = df["Distances(m)"].apply(make_prompt)
df.to_csv(file_path, index=False)

# %%
data_root = Path(r"X:\数据集\DeepShip\data_preprocessing\data")
annotation_root = Path(r"X:\数据集\DeepShip\annotation_original")

meta_files = {
    "Cargo": annotation_root / "cargo-metafile.csv",
    "Passengership": annotation_root / "passengership-metafile.csv",
    "Tanker": annotation_root / "tanker-metafile.csv",
    "Tug": annotation_root / "tug-metafile.csv",
}

def parse_id(folder_name: str) -> int | None:
    parts = folder_name.rsplit("-", 1)
    if len(parts) != 2 or not parts[1].isdigit():
        return None
    return int(parts[1])

summary = {}

for cls, meta_path in meta_files.items():
    annotation = pd.read_csv(meta_path)
    expected_ids = set(annotation["ID"].astype(int))

    cls_dir = data_root / cls
    if not cls_dir.exists():
        summary[cls] = {"error": f"目录不存在: {cls_dir}"}
        continue

    folder_ids: dict[int, Path] = {}
    invalid_names: list[str] = []
    duplicate_names: list[str] = []

    for subdir in cls_dir.iterdir():
        if not subdir.is_dir():
            continue
        sid = parse_id(subdir.name)
        if sid is None:
            invalid_names.append(subdir.name)
            continue
        # 如果同一个 ID 出现多个文件夹，记录重复名称
        if sid in folder_ids:
            duplicate_names.append(subdir.name)
        else:
            folder_ids[sid] = subdir

    observed_ids = set(folder_ids)
    missing_ids = sorted(expected_ids - observed_ids)
    extra_ids = sorted(observed_ids - expected_ids)

    missing_audio = []
    renamed_audio = []

    for sid, folder in folder_ids.items():
        expected_wav = folder / f"{sid}.wav"
        if expected_wav.exists():
            # 名称已经对上
            continue

        # 这里没有标准命名，尝试重命名
        wav_files = list(folder.glob("*.wav"))

        if len(wav_files) == 1:
            src = wav_files[0]
            src.rename(expected_wav)
            renamed_audio.append(f"{src.name} -> {expected_wav.name}")
        elif len(wav_files) > 1:
            missing_audio.append(
                f"{folder}（发现多个 wav：{', '.join(f.name for f in wav_files)}）"
            )
        else:
            missing_audio.append(f"{expected_wav}（文件夹没有 wav）")

    summary[cls] = {
        "annotated_count": len(expected_ids),
        "folder_count": len(observed_ids),
        "missing_ids": missing_ids,
        "extra_ids": extra_ids,
        "invalid_folder_names": invalid_names,
        "duplicate_folder_names": duplicate_names,
        "missing_wav_files": missing_audio,
        "renamed_wav_files": renamed_audio if renamed_audio else "OK",
    }

for cls, info in summary.items():
    print(cls)
    for key, value in info.items():
        if isinstance(value, list):
            print(f"  {key}: {value if value else 'OK'}")
        else:
            print(f"  {key}: {value}")
    print("-" * 40)
# Out:
# Cargo
#   annotated_count: 110
#   folder_count: 109
#   missing_ids: [23]
#   extra_ids: OK
#   invalid_folder_names: OK
#   duplicate_folder_names: OK
#   missing_wav_files: OK
#   renamed_wav_files: ['002044.wav -> 22.wav', '045829.wav -> 24.wav', '055206.wav -> 25.wav', '225044.wav -> 26.wav', '074918.wav -> 28.wav', '151043.wav -> 29.wav', '214753.wav -> 30.wav', '031902.wav -> 31.wav', '111158.wav -> 32.wav', '202039.wav -> 33.wav', '210343.wav -> 34.wav', '060651.wav -> 35.wav', '075414.wav -> 36.wav', '113017.wav -> 37.wav', '004508.wav -> 39.wav', '135730.wav -> 40.wav', '134001.wav -> 42.wav', '161634.wav -> 43.wav', '134833.wav -> 46.wav', '214505.wav -> 47.wav', '234924.wav -> 48.wav', '023314.wav -> 49.wav', '035027.wav -> 50.wav', '044753.wav -> 51.wav', '063408.wav -> 52.wav', '231436.wav -> 53.wav', '080742.wav -> 54.wav', '000645.wav -> 55.wav', '075459.wav -> 56.wav', '165031.wav -> 57.wav', '231720.wav -> 58.wav', '080357.wav -> 59.wav', '111402.wav -> 60.wav', '054923.wav -> 61.wav', '123015.wav -> 63.wav', '141802.wav -> 64.wav', '191824.wav -> 65.wav', '024305.wav -> 66.wav', '051220.wav -> 67.wav', '201125.wav -> 68.wav', '030344.wav -> 70.wav', '111659.wav -> 71.wav', '114551.wav -> 72.wav', '124454.wav -> 73.wav', '140834.wav -> 74.wav', '202122.wav -> 75.wav', '004911.wav -> 76.wav', '014907.wav -> 77.wav', '010450.wav -> 79.wav', '013045.wav -> 80.wav', '032120.wav -> 81.wav', '100039.wav -> 82.wav', '190947.wav -> 83.wav', '005033.wav -> 84.wav', '001029.wav -> 85.wav', '054935.
# ----------------------------------------

# %%
annotations = pd.read_csv(r"X:\数据集\DeepShip\data_preprocessing\annotation\DeepShip.csv")
data_root = Path(r"X:\数据集\DeepShip\data_preprocessing\data")

class_dirs = {
    0: "Cargo",
    1: "Passengership",
    2: "Tanker",
    3: "Tug",
}

for _, row in annotations.iterrows():
    cls_id = int(row["class_id"])
    sample_id = int(row["ID"])
    folder_name = row["folder_name"]

    if pd.isna(folder_name):
        print(f"ID:{sample_id}缺少folder_name，跳过ID:{sample_id}, class_id:{cls_id}")
        continue

    subdir = class_dirs.get(cls_id)
    if subdir is None:
        print(f"未知 class_id={cls_id}，跳过")
        continue

    src_dir = data_root / subdir / str(folder_name)
    if not src_dir.exists():
        print(f"目录不存在: {src_dir}")
        continue

    src_file = src_dir / f"{sample_id}.wav"
    dst_file = src_dir / f"{cls_id}_{sample_id}.wav"

    if dst_file.exists():
        print(f"目标名已存在，跳过: {dst_file}")
        continue

    src_file.rename(dst_file)
# Out:
# ID:23缺少folder_name，跳过ID:23, class_id:0

# %%
from pathlib import Path
import shutil

# %%
# 原目录
root = Path(r"X:\数据集\DeepShip\data_preprocessing")
categories = ["Cargo", "Passengership", "Tanker", "Tug"]
# 目标目录：同级生成 data_new/Cargo
dest_root = Path(r"X:\数据集\DeepShip\data_preprocessing\data_audio_rename")

# 需要的音频后缀，可按需扩展
audio_suffixes = {".wav"}

for category in categories:
    src_dir = root / "data" / category
    dst_dir = dest_root / category
    dst_dir.mkdir(parents=True, exist_ok=True)

    for audio in src_dir.rglob("*"):
        if audio.is_file() and audio.suffix.lower() in audio_suffixes:
            target = dst_dir / audio.name
            if target.exists():
                print(f"[跳过] {category}/{audio.name} 已存在，未覆盖。")
                continue
            shutil.copy2(audio, target)
            print(f"[复制] {audio.relative_to(root)} -> {target.relative_to(root)}")
# Out:
# [复制] data\Cargo\20171104-1\0_1.wav -> data_audio_rename\Cargo\0_1.wav
# [复制] data\Cargo\20171104a-2\0_2.wav -> data_audio_rename\Cargo\0_2.wav
# [复制] data\Cargo\20171105a-3\0_3.wav -> data_audio_rename\Cargo\0_3.wav
# [复制] data\Cargo\20171106-4\0_4.wav -> data_audio_rename\Cargo\0_4.wav
# [复制] data\Cargo\20171107-5\0_5.wav -> data_audio_rename\Cargo\0_5.wav
# [复制] data\Cargo\20171107b-6\0_6.wav -> data_audio_rename\Cargo\0_6.wav
# [复制] data\Cargo\20171110-7\0_7.wav -> data_audio_rename\Cargo\0_7.wav
# [复制] data\Cargo\20171111-8\0_8.wav -> data_audio_rename\Cargo\0_8.wav
# [复制] data\Cargo\20171111e-9\0_9.wav -> data_audio_rename\Cargo\0_9.wav
# [复制] data\Cargo\20171111f-10\0_10.wav -> data_audio_rename\Cargo\0_10.wav
# [复制] data\Cargo\20171111g-11\0_11.wav -> data_audio_rename\Cargo\0_11.wav
# [复制] data\Cargo\20171112-12\0_12.wav -> data_audio_rename\Cargo\0_12.wav
# [复制] data\Cargo\20171113-13\0_13.wav -> data_audio_rename\Cargo\0_13.wav
# [复制] data\Cargo\20171114a-14\0_14.wav -> data_audio_rename\Cargo\0_14.wav
# [复制] data\Cargo\20171114b-15\0_15.wav -> data_audio_rename\Cargo\0_15.wav
# [复制] data\Cargo\20171114c-16\0_16.wav -> data_audio_rename\Cargo\0_16.wav
# [复制] data\Cargo\20171114d-17\0_17.wav -> data_audio_rename\Cargo\0_17.wav
# [复制] data\Cargo\20171115a-18\0_18.wav -> data_audio_rename\Cargo\0_18.wav
# [复制] data\Cargo\20171115b-19\0_19.wav -> data_audio_rename\Cargo\0_19.wav
# [复制] data\Cargo\20171115d-20\0_20.wav -> data_audio_rename\Cargo\0_20.wav
# [复制] data\Cargo\20171116-22\0_22.wav -> data_audio_rename\Cargo\0_22.wav
# [复制] data\Cargo\20171117a-24\0_24.wav -> data_audio_rename\Cargo\0_24.wav
# [复制] data\Cargo\20171117b-25\0_25.wav -> data_audio_rename\Cargo\0_25.wav
# [复制] data\Cargo\20171117d-26\0_26.wav -> data_audio_rename\Cargo\0_26.wav
# [复制] data\Cargo\20171118-27\0_27.wav -> data_audio_rename\Cargo\0_27.wav
# [复制] data\Cargo\20171118a-28\0_28.wav -> data_audio_rename\Cargo\0_28.wav
# [复制] data\Cargo\20171119b-29\0_29.wav -> data_audio_rename\Cargo\0_29.wav
# [复制] data\Cargo\20171120-30\0_30.wav -> data_audio_rename\Cargo\0_30.wav
# [复制] data\Cargo\20171121-31\0_31.wav -> data_audio_rename\Cargo\0_31.wav
# [复制] data\Cargo\20171121c-32\0_32.wav -> data_audio_rename\Cargo\0_32.wav
# [复制] data\Cargo\20171121e-33\0_33.wav -> data_audio_rename\Cargo\0_33.wav
# [复制] data\Cargo\20171121f-34\0_34.wav -> data_audio_rename\Cargo\0_34.wav
# [复制] data\Cargo\20171122a-35\0_35.wav -> data_audio_rename\Cargo\0_35.wav
# [复制] data\Cargo\20171122b-36\0_36.wav -> data_audio_rename\Cargo\0_36.wav
# [复制] data\Cargo\20171122c-37\0_37.wav -> data_audio_rename\Cargo\0_37.wav
# [复制] data\Cargo\20171122d-38\0_38.wav -> data_audio_rename\Cargo\0_38.wav
# [复制] data\Cargo\20171123-39\0_39.wav -> data_audio_rename\Cargo\0_39.wav
# [复制] data\Cargo\20171123c-40\0_40.wav -> data_audio_rename\Cargo\0_40.wav
# [复制] data\Cargo\20171124a-41\0_41.wav -> data_audio_rename\Cargo\0_41.wav
# [复制] data\Cargo\20171124c-42\0_42.wav -> data_audio_rename\Cargo\0_42.wav
# [复制] data\Cargo\20171124d-43\0_43.wav -> data_audio_rename\Cargo\0_43.wav
# [复制] data\Cargo\20171125-44\0_44.wav -> data_audio_rename\Cargo\0_44.wav
# [复制] data\Cargo\20171125b-45\0_45.wav -> data_audio_rename\Cargo\0_45.wav
# [复制] data\Cargo\20171125c-46\0_46.wav -> data_audio_rename\Cargo\0_46.wav
# [复制] data\Cargo\20171125d-47\0_47.wav -> data_audio_rename\Cargo\0_47.wav
# [复制] data\Cargo\20171125e-48\0_48.wav -> data_audio_rename\Cargo\0_48.wav
# [复制] data\Cargo\20171126-49\0_49.wav -> data_audio_rename\Cargo\0_49.wav
# [复制] data\Cargo\20171126a-50\0_50.wav -> data_audio_rename\Cargo\0_50.wav
# [复制] data\Cargo\20171126b-51\0_51.wav -> data_audio_rename\Cargo\0_51.wav
# [复制] data\Cargo\20171126c-52\0_52.wav -> data_audio_rename\Cargo\0_52.wav
# [复制] data\Cargo\20171127-53\0_53.wav -> data_audio_rename\Cargo\0_53.wav
# [复制] data\Cargo\20171128a-54\0_54.wav -> data_audio_rename\Cargo\0_54.wav
# [复制] data\Cargo\20171129-55\0_55.wav -> data_audio_rename\Cargo\0_55.wav
# [复制] data\Cargo\20171129c-56\0_56.wav -> data_audio_rename\Cargo\0_56.wav
# [复制] data\Cargo\20171130-57\0_57.wav -> data_audio_rename\Cargo\0_57.wav
# [复制] data\Cargo\20171130c-58\0_58.wav -> data_audio_rename\Cargo\0_58.wav
# [复制] data\Cargo\20171201-59\0_59.wav -> data_audio_rename\Cargo\0_59.wav
# [复制] data\Cargo\20171201a-60\0_60.wav -> data_audio_rename\Cargo\0_60.wav
# [复制] data\Cargo\20171202a-61\0_61.wav -> data_audio_rename\Cargo\0_61.wav
# [复制] data\Cargo\20171202b-62\0_62.wav -> data_audio_rename\Cargo\0_62.wav
# [复制] data\Cargo\20171202c-63\0_63.wav -> data_audio_rename\Cargo\0_63.wav
# [复制] data\Cargo\20171202e-64\0_64.wav -> data_audio_rename\Cargo\0_64.wav
# [复制] data\Cargo\20171203-65\0_65.wav -> data_audio_rename\Cargo\0_65.wav
# [复制] data\Cargo\20171204-66\0_66.wav -> data_audio_rename\Cargo\0_66.wav
# [复制] data\Cargo\20171204a-67\0_67.wav -> data_audio_rename\Cargo\0_67.wav
# [复制] data\Cargo\20171204b-68\0_68.wav -> data_audio_rename\Cargo\0_68.wav
# [复制] data\Cargo\20171205-69\0_69.wav -> data_audio_rename\Cargo\0_69.wav
# [复制] data\Cargo\20171205a-70\0_70.wav -> data_audio_rename\Cargo\0_70.wav
# [复制] data\Cargo\20171205e-71\0_71.wav -> data_audio_rename\Cargo\0_71.wav
# [复制] data\Cargo\20171205f-72\0_72.wav -> data_audio_rename\Cargo\0_72.wav
# [复制] data\Cargo\20171205g-73\0_73.wav -> data_audio_rename\Cargo\0_73.wav
# [复制] data\Cargo\20171205h-74\0_74.wav -> data_audio_rename\Cargo\0_74.wav
# [复制] data\Cargo\20171205i-75\0_75.wav -> data_audio_rename\Cargo\0_75.wav
# [复制] data\Cargo\20171206-76\0_76.wav -> data_audio_rename\Cargo\0_76.wav
# [复制] data\Cargo\20171206a-77\0_77.wav -> data_audio_rename\Cargo\0_77.wav
# [复制] data\Cargo\20171206e-78\0_78.wav -> data_audio_rename\Cargo\0_78.wav
# [复制] data\Cargo\20171207-79\0_79.wav -> data_audio_rename\Cargo\0_79.wav
# [复制] data\Cargo\20171207a-80\0_80.wav -> data_audio_rename\Cargo\0_80.wav
# [复制] data\Cargo\20171207b-81\0_81.wav -> data_audio_rename\Cargo\0_81.wav
# [复制] data\Cargo\20171207d-82\0_82.wav -> data_audio_rename\Cargo\0_82.wav
# [复制] data\Cargo\20171207f-83\0_83.wav -> data_audio_rename\Cargo\0_83.wav
# [复制] data\Cargo\20171208-84\0_84.wav -> data_audio_rename\Cargo\0_84.wav
# [复制] data\Cargo\20171209-85\0_85.wav -> data_audio_rename\Cargo\0_85.wav
# [复制] data\Cargo\20171209b-86\0_86.wav -> data_audio_rename\Cargo\0_86.wav
# [复制] data\Cargo\20171209c-87\0_87.wav -> data_audio_rename\Cargo\0_87.wav
# [复制] data\Cargo\20171210-88\0_88.wav -> data_audio_rename\Cargo\0_88.wav
# [复制] data\Cargo\20171210a-89\0_89.wav -> data_audio_rename\Cargo\0_89.wav
# [复制] data\Cargo\20171210c-90\0_90.wav -> data_audio_rename\Cargo\0_90.wav
# [复制] data\Cargo\20171212a-91\0_91.wav -> data_audio_rename\Cargo\0_91.wav
# [复制] data\Cargo\20171212b-92\0_92.wav -> data_audio_rename\Cargo\0_92.wav
# [复制] data\Cargo\20171212c-93\0_93.wav -> data_audio_rename\Cargo\0_93.wav
# [复制] data\Cargo\20171212d-94\0_94.wav -> data_audio_rename\Cargo\0_94.wav
# [复制] data\Cargo\20171213-95\0_95.wav -> data_audio_rename\Cargo\0_95.wav
# [复制] data\Cargo\20171213b-96\0_96.wav -> data_audio_rename\Cargo\0_96.wav
# [复制] data\Cargo\20171213d-97\0_97.wav -> data_audio_rename\Cargo\0_97.wav
# [复制] data\Cargo\20171213e-98\0_98.wav -> data_audio_rename\Cargo\0_98.wav
# [复制] data\Cargo\20171213f-99\0_99.wav -> data_audio_rename\Cargo\0_99.wav
# [复制] data\Cargo\20171213g-100\0_100.wav -> data_audio_rename\Cargo\0_100.wav
# [复制] data\Cargo\20171214a-101\0_101.wav -> data_audio_rename\Cargo\0_101.wav
# [复制] data\Cargo\20171214b-102\0_102.wav -> data_audio_rename\Cargo\0_102.wav
# [复制] data\Cargo\20171214d-103\0_103.wav -> data_audio_rename\Cargo\0_103.wav
# [复制] data\Cargo\20171214e-104\0_104.wav -> data_audio_rename\Cargo\0_104.wav
# [复制] data\Cargo\20171214f-105\0_105.wav -> data_audio_rename\Cargo\0_105.wav
# [复制] data\Cargo\20171215-106\0_106.wav -> data_audio_rename\Cargo\0_106.wav
# [复制] data\Cargo\20171215a-107\0_107.wav -> data_audio_rename\Cargo\0_107.wav
# [复制] data\Cargo\20171215b-108\0_108.wav -> data_audio_rename\Cargo\0_108.wav
# [复制] data\Cargo\20171215c-109\0_109.wav -> data_audio_rename\Cargo\0_109.wav
# [复制] data\Cargo\20171215d-110\0_110.wav -> data_audio_rename\Cargo\0_110.wav
# [复制] data\Tanker\20160516-4\2_4.wav -> data_audio_rename\Tanker\2_4.wav
# [复制] data\Tanker\20160519-5\2_5.wav -> data_audio_rename\Tanker\2_5.wav
# [复制] data\Tanker\20160526-6\2_6.wav -> data_audio_rename\Tanker\2_6.wav
# [复制] data\Tanker\20160531-7\2_7.wav -> data_audio_rename\Tanker\2_7.wav
# [复制] data\Tanker\20160601-8\2_8.wav -> data_audio_rename\Tanker\2_8.wav
# [复制] data\Tanker\20160602-9\2_9.wav -> data_audio_rename\Tanker\2_9.wav
# [复制] data\Tanker\20160602a-10\2_10.wav -> data_audio_rename\Tanker\2_10.wav
# [复制] data\Tanker\20160604-11\2_11.wav -> data_audio_rename\Tanker\2_11.wav
# [复制] data\Tanker\20160612-12\2_12.wav -> data_audio_rename\Tanker\2_12.wav
# [复制] data\Tanker\20160613-13\2_13.wav -> data_audio_rename\Tanker\2_13.wav
# [复制] data\Tanker\20160615-14\2_14.wav -> data_audio_rename\Tanker\2_14.wav
# [复制] data\Tanker\20160616-15\2_15.wav -> data_audio_rename\Tanker\2_15.wav
# [复制] data\Tanker\20160617-16\2_16.wav -> data_audio_rename\Tanker\2_16.wav
# [复制] data\Tanker\20160619-17\2_17.wav -> data_audio_rename\Tanker\2_17.wav
# [复制] data\Tanker\20160619a-18\2_18.wav -> data_audio_rename\Tanker\2_18.wav
# [复制] data\Tanker\20160625-19\2_19.wav -> data_audio_rename\Tanker\2_19.wav
# [复制] data\Tanker\20160702-20\2_20.wav -> data_audio_rename\Tanker\2_20.wav
# [复制] data\Tanker\20160703-21\2_21.wav -> data_audio_rename\Tanker\2_21.wav
# [复制] data\Tanker\20160704-22\2_22.wav -> data_audio_rename\Tanker\2_22.wav
# [复制] data\Tanker\20160710-23\2_23.wav -> data_audio_rename\Tanker\2_23.wav
# [复制] data\Tanker\20160710a-24\2_24.wav -> data_audio_rename\Tanker\2_24.wav
# [复制] data\Tanker\20160714-25\2_25.wav -> data_audio_rename\Tanker\2_25.wav
# [复制] data\Tanker\20160714a-26\2_26.wav -> data_audio_rename\Tanker\2_26.wav
# [复制] data\Tanker\20160724-27\2_27.wav -> data_audio_rename\Tanker\2_27.wav
# [复制] data\Tanker\20160808-28\2_28.wav -> data_audio_rename\Tanker\2_28.wav
# [复制] data\Tanker\20160810-29\2_29.wav -> data_audio_rename\Tanker\2_29.wav
# [复制] data\Tanker\20160810a-30\2_30.wav -> data_audio_rename\Tanker\2_30.wav
# [复制] data\Tanker\20160823-31\2_31.wav -> data_audio_rename\Tanker\2_31.wav
# [复制] data\Tanker\20160829-32\2_32.wav -> data_audio_rename\Tanker\2_32.wav
# [复制] data\Tanker\20160831-33\2_33.wav -> data_audio_rename\Tanker\2_33.wav
# [复制] data\Tanker\20160904-34\2_34.wav -> data_audio_rename\Tanker\2_34.wav
# [复制] data\Tanker\20160906-35\2_35.wav -> data_audio_rename\Tanker\2_35.wav
# [复制] data\Tanker\20160907-36\2_36.wav -> data_audio_rename\Tanker\2_36.wav
# [复制] data\Tanker\20160910-37\2_37.wav -> data_audio_rename\Tanker\2_37.wav
# [复制] data\Tanker\20160924-38\2_38.wav -> data_audio_rename\Tanker\2_38.wav
# [复制] data\Tanker\20160927-39\2_39.wav -> data_audio_rename\Tanker\2_39.wav
# [复制] data\Tanker\20161002-40\2_40.wav -> data_audio_rename\Tanker\2_40.wav
# [复制] data\Tanker\20161005-41\2_41.wav -> data_audio_rename\Tanker\2_41.wav
# [复制] data\Tanker\20161009-42\2_42.wav -> data_audio_rename\Tanker\2_42.wav
# [复制] data\Tanker\20161021-43\2_43.wav -> data_audio_rename\Tanker\2_43.wav
# [复制] data\Tanker\20161022-44\2_44.wav -> data_audio_rename\Tanker\2_44.wav
# [复制] data\Tanker\20161024-45\2_45.wav -> data_audio_rename\Tanker\2_45.wav
# [复制] data\Tanker\20161027-46\2_46.wav -> data_audio_rename\Tanker\2_46.wav
# [复制] data\Tanker\20161030-47\2_47.wav -> data_audio_rename\Tanker\2_47.wav
# [复制] data\Tanker\20161101-48\2_48.wav -> data_audio_rename\Tanker\2_48.wav
# [复制] data\Tanker\20161101a-49\2_49.wav -> data_audio_rename\Tanker\2_49.wav
# [复制] data\Tanker\20161106-50\2_50.wav -> data_audio_rename\Tanker\2_50.wav
# [复制] data\Tanker\20161107-51\2_51.wav -> data_audio_rename\Tanker\2_51.wav
# [复制] data\Tanker\20161110-52\2_52.wav -> data_audio_rename\Tanker\2_52.wav
# [复制] data\Tanker\20161113-237\2_237.wav -> data_audio_rename\Tanker\2_237.wav
# [复制] data\Tanker\20161113a-53\2_53.wav -> data_audio_rename\Tanker\2_53.wav
# [复制] data\Tanker\20161121-54\2_54.wav -> data_audio_rename\Tanker\2_54.wav
# [复制] data\Tanker\20161123-55\2_55.wav -> data_audio_rename\Tanker\2_55.wav
# [复制] data\Tanker\20161124-56\2_56.wav -> data_audio_rename\Tanker\2_56.wav
# [复制] data\Tanker\20161125-57\2_57.wav -> data_audio_rename\Tanker\2_57.wav
# [复制] data\Tanker\20161128-58\2_58.wav -> data_audio_rename\Tanker\2_58.wav
# [复制] data\Tanker\20161206-59\2_59.wav -> data_audio_rename\Tanker\2_59.wav
# [复制] data\Tanker\20161207-60\2_60.wav -> data_audio_rename\Tanker\2_60.wav
# [复制] data\Tanker\20161208-61\2_61.wav -> data_audio_rename\Tanker\2_61.wav
# [复制] data\Tanker\20161208a-62\2_62.wav -> data_audio_rename\Tanker\2_62.wav
# [复制] data\Tanker\20161211-63\2_63.wav -> data_audio_rename\Tanker\2_63.wav
# [复制] data\Tanker\20161215-64\2_64.wav -> data_audio_rename\Tanker\2_64.wav
# [复制] data\Tanker\20161218-65\2_65.wav -> data_audio_rename\Tanker\2_65.wav
# [复制] data\Tanker\20161226-66\2_66.wav -> data_audio_rename\Tanker\2_66.wav
# [复制] data\Tanker\20161227-67\2_67.wav -> data_audio_rename\Tanker\2_67.wav
# [复制] data\Tanker\20170102-68\2_68.wav -> data_audio_rename\Tanker\2_68.wav
# [复制] data\Tanker\20170119-69\2_69.wav -> data_audio_rename\Tanker\2_69.wav
# [复制] data\Tanker\20170120-70\2_70.wav -> data_audio_rename\Tanker\2_70.wav
# [复制] data\Tanker\20170121-71\2_71.wav -> data_audio_rename\Tanker\2_71.wav
# [复制] data\Tanker\20170122-72\2_72.wav -> data_audio_rename\Tanker\2_72.wav
# [复制] data\Tanker\20170122a-73\2_73.wav -> data_audio_rename\Tanker\2_73.wav
# [复制] data\Tanker\20170122b-74\2_74.wav -> data_audio_rename\Tanker\2_74.wav
# [复制] data\Tanker\20170124-75\2_75.wav -> data_audio_rename\Tanker\2_75.wav
# [复制] data\Tanker\20170203-76\2_76.wav -> data_audio_rename\Tanker\2_76.wav
# [复制] data\Tanker\20170204-77\2_77.wav -> data_audio_rename\Tanker\2_77.wav
# [复制] data\Tanker\20170205-78\2_78.wav -> data_audio_rename\Tanker\2_78.wav
# [复制] data\Tanker\20170206-79\2_79.wav -> data_audio_rename\Tanker\2_79.wav
# [复制] data\Tanker\20170209-80\2_80.wav -> data_audio_rename\Tanker\2_80.wav
# [复制] data\Tanker\20170216-81\2_81.wav -> data_audio_rename\Tanker\2_81.wav
# [复制] data\Tanker\20170219-82\2_82.wav -> data_audio_rename\Tanker\2_82.wav
# [复制] data\Tanker\20170227-83\2_83.wav -> data_audio_rename\Tanker\2_83.wav
# [复制] data\Tanker\20170301-84\2_84.wav -> data_audio_rename\Tanker\2_84.wav
# [复制] data\Tanker\20170309-85\2_85.wav -> data_audio_rename\Tanker\2_85.wav
# [复制] data\Tanker\20170317-86\2_86.wav -> data_audio_rename\Tanker\2_86.wav
# [复制] data\Tanker\20170326-87\2_87.wav -> data_audio_rename\Tanker\2_87.wav
# [复制] data\Tanker\20170326a-88\2_88.wav -> data_audio_rename\Tanker\2_88.wav
# [复制] data\Tanker\20170326b-89\2_89.wav -> data_audio_rename\Tanker\2_89.wav
# [复制] data\Tanker\20170327-90\2_90.wav -> data_audio_rename\Tanker\2_90.wav
# [复制] data\Tanker\20170327a-91\2_91.wav -> data_audio_rename\Tanker\2_91.wav
# [复制] data\Tanker\20170403-92\2_92.wav -> data_audio_rename\Tanker\2_92.wav
# [复制] data\Tanker\20170403a-93\2_93.wav -> data_audio_rename\Tanker\2_93.wav
# [复制] data\Tanker\20170404-94\2_94.wav -> data_audio_rename\Tanker\2_94.wav
# [复制] data\Tanker\20170409-95\2_95.wav -> data_audio_rename\Tanker\2_95.wav
# [复制] data\Tanker\20170412-96\2_96.wav -> data_audio_rename\Tanker\2_96.wav
# [复制] data\Tanker\20170413-97\2_97.wav -> data_audio_rename\Tanker\2_97.wav
# [复制] data\Tanker\20170419-98\2_98.wav -> data_audio_rename\Tanker\2_98.wav
# [复制] data\Tanker\20170420-99\2_99.wav -> data_audio_rename\Tanker\2_99.wav
# [复制] data\Tanker\20170421-100\2_100.wav -> data_audio_rename\Tanker\2_100.wav
# [复制] data\Tanker\20170421a-101\2_101.wav -> data_audio_rename\Tanker\2_101.wav
# [复制] data\Tanker\20170425-102\2_102.wav -> data_audio_rename\Tanker\2_102.wav
# [复制] data\Tanker\20170507-103\2_103.wav -> data_audio_rename\Tanker\2_103.wav
# [复制] data\Tanker\20170509-104\2_104.wav -> data_audio_rename\Tanker\2_104.wav
# [复制] data\Tanker\20170510-105\2_105.wav -> data_audio_rename\Tanker\2_105.wav
# [复制] data\Tanker\20170511-106\2_106.wav -> data_audio_rename\Tanker\2_106.wav
# [复制] data\Tanker\20170512-107\2_107.wav -> data_audio_rename\Tanker\2_107.wav
# [复制] data\Tanker\20170516-108\2_108.wav -> data_audio_rename\Tanker\2_108.wav
# [复制] data\Tanker\20170525-109\2_109.wav -> data_audio_rename\Tanker\2_109.wav
# [复制] data\Tanker\20170529-110\2_110.wav -> data_audio_rename\Tanker\2_110.wav
# [复制] data\Tanker\20170530-111\2_111.wav -> data_audio_rename\Tanker\2_111.wav
# [复制] data\Tanker\20170605-112\2_112.wav -> data_audio_rename\Tanker\2_112.wav
# [复制] data\Tanker\20170608-113\2_113.wav -> data_audio_rename\Tanker\2_113.wav
# [复制] data\Tanker\20170612-114\2_114.wav -> data_audio_rename\Tanker\2_114.wav
# [复制] data\Tanker\20170614-115\2_115.wav -> data_audio_rename\Tanker\2_115.wav
# [复制] data\Tanker\20170621-116\2_116.wav -> data_audio_rename\Tanker\2_116.wav
# [复制] data\Tanker\20170623-117\2_117.wav -> data_audio_rename\Tanker\2_117.wav
# [复制] data\Tanker\20170625-118\2_118.wav -> data_audio_rename\Tanker\2_118.wav
# [复制] data\Tanker\20170627-119\2_119.wav -> data_audio_rename\Tanker\2_119.wav
# [复制] data\Tanker\20170629-120\2_120.wav -> data_audio_rename\Tanker\2_120.wav
# [复制] data\Tanker\20170630-121\2_121.wav -> data_audio_rename\Tanker\2_121.wav
# [复制] data\Tanker\20170704-122\2_122.wav -> data_audio_rename\Tanker\2_122.wav
# [复制] data\Tanker\20170705-123\2_123.wav -> data_audio_rename\Tanker\2_123.wav
# [复制] data\Tanker\20170711-124\2_124.wav -> data_audio_rename\Tanker\2_124.wav
# [复制] data\Tanker\20170711a-239\2_239.wav -> data_audio_rename\Tanker\2_239.wav
# [复制] data\Tanker\20170712-125\2_125.wav -> data_audio_rename\Tanker\2_125.wav
# [复制] data\Tanker\20170712a-126\2_126.wav -> data_audio_rename\Tanker\2_126.wav
# [复制] data\Tanker\20170720-127\2_127.wav -> data_audio_rename\Tanker\2_127.wav
# [复制] data\Tanker\20170723-238\2_238.wav -> data_audio_rename\Tanker\2_238.wav
# [复制] data\Tanker\20170723a-128\2_128.wav -> data_audio_rename\Tanker\2_128.wav
# [复制] data\Tanker\20170728-129\2_129.wav -> data_audio_rename\Tanker\2_129.wav
# [复制] data\Tanker\20170802-130\2_130.wav -> data_audio_rename\Tanker\2_130.wav
# [复制] data\Tanker\20170815-131\2_131.wav -> data_audio_rename\Tanker\2_131.wav
# [复制] data\Tanker\20170818-132\2_132.wav -> data_audio_rename\Tanker\2_132.wav
# [复制] data\Tanker\20170822-133\2_133.wav -> data_audio_rename\Tanker\2_133.wav
# [复制] data\Tanker\20170824-134\2_134.wav -> data_audio_rename\Tanker\2_134.wav
# [复制] data\Tanker\20170826-135\2_135.wav -> data_audio_rename\Tanker\2_135.wav
# [复制] data\Tanker\20170828-136\2_136.wav -> data_audio_rename\Tanker\2_136.wav
# [复制] data\Tanker\20170901-137\2_137.wav -> data_audio_rename\Tanker\2_137.wav
# [复制] data\Tanker\20170909-138\2_138.wav -> data_audio_rename\Tanker\2_138.wav
# [复制] data\Tanker\20170920-139\2_139.wav -> data_audio_rename\Tanker\2_139.wav
# [复制] data\Tanker\20170923-140\2_140.wav -> data_audio_rename\Tanker\2_140.wav
# [复制] data\Tanker\20171008-141\2_141.wav -> data_audio_rename\Tanker\2_141.wav
# [复制] data\Tanker\20171013-142\2_142.wav -> data_audio_rename\Tanker\2_142.wav
# [复制] data\Tanker\20171014-143\2_143.wav -> data_audio_rename\Tanker\2_143.wav
# [复制] data\Tanker\20171015-144\2_144.wav -> data_audio_rename\Tanker\2_144.wav
# [复制] data\Tanker\20171023-145\2_145.wav -> data_audio_rename\Tanker\2_145.wav
# [复制] data\Tanker\20171024-146\2_146.wav -> data_audio_rename\Tanker\2_146.wav
# [复制] data\Tanker\20171029-147\2_147.wav -> data_audio_rename\Tanker\2_147.wav
# [复制] data\Tanker\20171031-148\2_148.wav -> data_audio_rename\Tanker\2_148.wav
# [复制] data\Tanker\20171108-149\2_149.wav -> data_audio_rename\Tanker\2_149.wav
# [复制] data\Tanker\20171110-150\2_150.wav -> data_audio_rename\Tanker\2_150.wav
# [复制] data\Tanker\20171121-151\2_151.wav -> data_audio_rename\Tanker\2_151.wav
# [复制] data\Tanker\20171126-152\2_152.wav -> data_audio_rename\Tanker\2_152.wav
# [复制] data\Tanker\20171126a-153\2_153.wav -> data_audio_rename\Tanker\2_153.wav
# [复制] data\Tanker\20171127-154\2_154.wav -> data_audio_rename\Tanker\2_154.wav
# [复制] data\Tanker\20171128-155\2_155.wav -> data_audio_rename\Tanker\2_155.wav
# [复制] data\Tanker\20171204-156\2_156.wav -> data_audio_rename\Tanker\2_156.wav
# [复制] data\Tanker\20171207-157\2_157.wav -> data_audio_rename\Tanker\2_157.wav
# [复制] data\Tanker\20171208-158\2_158.wav -> data_audio_rename\Tanker\2_158.wav
# [复制] data\Tanker\20171216-159\2_159.wav -> data_audio_rename\Tanker\2_159.wav
# [复制] data\Tanker\20171220-240\2_240.wav -> data_audio_rename\Tanker\2_240.wav
# [复制] data\Tanker\20171222-160\2_160.wav -> data_audio_rename\Tanker\2_160.wav
# [复制] data\Tanker\20171222a-161\2_161.wav -> data_audio_rename\Tanker\2_161.wav
# [复制] data\Tanker\20171223-162\2_162.wav -> data_audio_rename\Tanker\2_162.wav
# [复制] data\Tanker\20171230-163\2_163.wav -> data_audio_rename\Tanker\2_163.wav
# [复制] data\Tanker\20171230a-164\2_164.wav -> data_audio_rename\Tanker\2_164.wav
# [复制] data\Tanker\20171230b-165\2_165.wav -> data_audio_rename\Tanker\2_165.wav
# [复制] data\Tanker\20180117-166\2_166.wav -> data_audio_rename\Tanker\2_166.wav
# [复制] data\Tanker\20180119-167\2_167.wav -> data_audio_rename\Tanker\2_167.wav
# [复制] data\Tanker\20180119a-168\2_168.wav -> data_audio_rename\Tanker\2_168.wav
# [复制] data\Tanker\20180120-169\2_169.wav -> data_audio_rename\Tanker\2_169.wav
# [复制] data\Tanker\20180120a-170\2_170.wav -> data_audio_rename\Tanker\2_170.wav
# [复制] data\Tanker\20180121-171\2_171.wav -> data_audio_rename\Tanker\2_171.wav
# [复制] data\Tanker\20180129-172\2_172.wav -> data_audio_rename\Tanker\2_172.wav
# [复制] data\Tanker\20180130-173\2_173.wav -> data_audio_rename\Tanker\2_173.wav
# [复制] data\Tanker\20180203-174\2_174.wav -> data_audio_rename\Tanker\2_174.wav
# [复制] data\Tanker\20180206-175\2_175.wav -> data_audio_rename\Tanker\2_175.wav
# [复制] data\Tanker\20180206a-176\2_176.wav -> data_audio_rename\Tanker\2_176.wav
# [复制] data\Tanker\20180208-177\2_177.wav -> data_audio_rename\Tanker\2_177.wav
# [复制] data\Tanker\20180211-178\2_178.wav -> data_audio_rename\Tanker\2_178.wav
# [复制] data\Tanker\20180221-179\2_179.wav -> data_audio_rename\Tanker\2_179.wav
# [复制] data\Tanker\20180226-180\2_180.wav -> data_audio_rename\Tanker\2_180.wav
# [复制] data\Tanker\20180303-181\2_181.wav -> data_audio_rename\Tanker\2_181.wav
# [复制] data\Tanker\20180311-182\2_182.wav -> data_audio_rename\Tanker\2_182.wav
# [复制] data\Tanker\20180314-183\2_183.wav -> data_audio_rename\Tanker\2_183.wav
# [复制] data\Tanker\20180314a-184\2_184.wav -> data_audio_rename\Tanker\2_184.wav
# [复制] data\Tanker\20180316-185\2_185.wav -> data_audio_rename\Tanker\2_185.wav
# [复制] data\Tanker\20180316a-186\2_186.wav -> data_audio_rename\Tanker\2_186.wav
# [复制] data\Tanker\20180402-187\2_187.wav -> data_audio_rename\Tanker\2_187.wav
# [复制] data\Tanker\20180405-188\2_188.wav -> data_audio_rename\Tanker\2_188.wav
# [复制] data\Tanker\20180411-189\2_189.wav -> data_audio_rename\Tanker\2_189.wav
# [复制] data\Tanker\20180411a-190\2_190.wav -> data_audio_rename\Tanker\2_190.wav
# [复制] data\Tanker\20180413-191\2_191.wav -> data_audio_rename\Tanker\2_191.wav
# [复制] data\Tanker\20180417-192\2_192.wav -> data_audio_rename\Tanker\2_192.wav
# [复制] data\Tanker\20180418-193\2_193.wav -> data_audio_rename\Tanker\2_193.wav
# [复制] data\Tanker\20180421-194\2_194.wav -> data_audio_rename\Tanker\2_194.wav
# [复制] data\Tanker\20180422-195\2_195.wav -> data_audio_rename\Tanker\2_195.wav
# [复制] data\Tanker\20180422a-196\2_196.wav -> data_audio_rename\Tanker\2_196.wav
# [复制] data\Tanker\20180422b-197\2_197.wav -> data_audio_rename\Tanker\2_197.wav
# [复制] data\Tanker\20180423-198\2_198.wav -> data_audio_rename\Tanker\2_198.wav
# [复制] data\Tanker\20180425-199\2_199.wav -> data_audio_rename\Tanker\2_199.wav
# [复制] data\Tanker\20180430-200\2_200.wav -> data_audio_rename\Tanker\2_200.wav
# [复制] data\Tanker\20180506-201\2_201.wav -> data_audio_rename\Tanker\2_201.wav
# [复制] data\Tanker\20180507-202\2_202.wav -> data_audio_rename\Tanker\2_202.wav
# [复制] data\Tanker\20180508-203\2_203.wav -> data_audio_rename\Tanker\2_203.wav
# [复制] data\Tanker\20180509-204\2_204.wav -> data_audio_rename\Tanker\2_204.wav
# [复制] data\Tanker\20180510-205\2_205.wav -> data_audio_rename\Tanker\2_205.wav
# [复制] data\Tanker\20180515-206\2_206.wav -> data_audio_rename\Tanker\2_206.wav
# [复制] data\Tanker\20180515a-207\2_207.wav -> data_audio_rename\Tanker\2_207.wav
# [复制] data\Tanker\20180519-208\2_208.wav -> data_audio_rename\Tanker\2_208.wav
# [复制] data\Tanker\20180520-209\2_209.wav -> data_audio_rename\Tanker\2_209.wav
# [复制] data\Tanker\20180523-210\2_210.wav -> data_audio_rename\Tanker\2_210.wav
# [复制] data\Tanker\20180529-211\2_211.wav -> data_audio_rename\Tanker\2_211.wav
# [复制] data\Tanker\20180602-212\2_212.wav -> data_audio_rename\Tanker\2_212.wav
# [复制] data\Tanker\20180604-213\2_213.wav -> data_audio_rename\Tanker\2_213.wav
# [复制] data\Tanker\20180607-214\2_214.wav -> data_audio_rename\Tanker\2_214.wav
# [复制] data\Tanker\20180610-215\2_215.wav -> data_audio_rename\Tanker\2_215.wav
# [复制] data\Tanker\20180612-216\2_216.wav -> data_audio_rename\Tanker\2_216.wav
# [复制] data\Tanker\20180612a-217\2_217.wav -> data_audio_rename\Tanker\2_217.wav
# [复制] data\Tanker\20180616-218\2_218.wav -> data_audio_rename\Tanker\2_218.wav
# [复制] data\Tanker\20180618-219\2_219.wav -> data_audio_rename\Tanker\2_219.wav
# [复制] data\Tanker\20180629-220\2_220.wav -> data_audio_rename\Tanker\2_220.wav
# [复制] data\Tanker\20180630-221\2_221.wav -> data_audio_rename\Tanker\2_221.wav
# [复制] data\Tanker\20180702-222\2_222.wav -> data_audio_rename\Tanker\2_222.wav
# [复制] data\Tanker\20180703-223\2_223.wav -> data_audio_rename\Tanker\2_223.wav
# [复制] data\Tanker\20180705-224\2_224.wav -> data_audio_rename\Tanker\2_224.wav
# [复制] data\Tanker\20180710-225\2_225.wav -> data_audio_rename\Tanker\2_225.wav
# [复制] data\Tanker\20180710a-226\2_226.wav -> data_audio_rename\Tanker\2_226.wav
# [复制] data\Tanker\20180725-227\2_227.wav -> data_audio_rename\Tanker\2_227.wav
# [复制] data\Tanker\20180725a-228\2_228.wav -> data_audio_rename\Tanker\2_228.wav
# [复制] data\Tanker\20180725b-229\2_229.wav -> data_audio_rename\Tanker\2_229.wav
# [复制] data\Tanker\20180821-230\2_230.wav -> data_audio_rename\Tanker\2_230.wav
# [复制] data\Tanker\20180822-231\2_231.wav -> data_audio_rename\Tanker\2_231.wav
# [复制] data\Tanker\20180826-232\2_232.wav -> data_audio_rename\Tanker\2_232.wav
# [复制] data\Tanker\20180904-233\2_233.wav -> data_audio_rename\Tanker\2_233.wav
# [复制] data\Tanker\20180914-234\2_234.wav -> data_audio_rename\Tanker\2_234.wav
# [复制] data\Tanker\20180915-235\2_235.wav -> data_audio_rename\Tanker\2_235.wav
# [复制] data\Tanker\20180927-236\2_236.wav -> data_audio_rename\Tanker\2_236.wav
# [复制] data\Tug\20171104-1\3_1.wav -> data_audio_rename\Tug\3_1.wav
# [复制] data\Tug\20171105-2\3_2.wav -> data_audio_rename\Tug\3_2.wav
# [复制] data\Tug\20171105b-3\3_3.wav -> data_audio_rename\Tug\3_3.wav
# [复制] data\Tug\20171106-4\3_4.wav -> data_audio_rename\Tug\3_4.wav
# [复制] data\Tug\20171106a-5\3_5.wav -> data_audio_rename\Tug\3_5.wav
# [复制] data\Tug\20171107a-6\3_6.wav -> data_audio_rename\Tug\3_6.wav
# [复制] data\Tug\20171111-7\3_7.wav -> data_audio_rename\Tug\3_7.wav
# [复制] data\Tug\20171114-8\3_8.wav -> data_audio_rename\Tug\3_8.wav
# [复制] data\Tug\20171115-9\3_9.wav -> data_audio_rename\Tug\3_9.wav
# [复制] data\Tug\20171116-10\3_10.wav -> data_audio_rename\Tug\3_10.wav
# [复制] data\Tug\20171116a-11\3_11.wav -> data_audio_rename\Tug\3_11.wav
# [复制] data\Tug\20171118-12\3_12.wav -> data_audio_rename\Tug\3_12.wav
# [复制] data\Tug\20171118a-13\3_13.wav -> data_audio_rename\Tug\3_13.wav
# [复制] data\Tug\20171118b-14\3_14.wav -> data_audio_rename\Tug\3_14.wav
# [复制] data\Tug\20171118c-15\3_15.wav -> data_audio_rename\Tug\3_15.wav
# [复制] data\Tug\20171118d-16\3_16.wav -> data_audio_rename\Tug\3_16.wav
# [复制] data\Tug\20171120-17\3_17.wav -> data_audio_rename\Tug\3_17.wav
# [复制] data\Tug\20171120a-18\3_18.wav -> data_audio_rename\Tug\3_18.wav
# [复制] data\Tug\20171121-19\3_19.wav -> data_audio_rename\Tug\3_19.wav
# [复制] data\Tug\20171122a-20\3_20.wav -> data_audio_rename\Tug\3_20.wav
# [复制] data\Tug\20171123-21\3_21.wav -> data_audio_rename\Tug\3_21.wav
# [复制] data\Tug\20171124-22\3_22.wav -> data_audio_rename\Tug\3_22.wav
# [复制] data\Tug\20171127-23\3_23.wav -> data_audio_rename\Tug\3_23.wav
# [复制] data\Tug\20171127a-24\3_24.wav -> data_audio_rename\Tug\3_24.wav
# [复制] data\Tug\20171128-25\3_25.wav -> data_audio_rename\Tug\3_25.wav
# [复制] data\Tug\20171221-61\3_61.wav -> data_audio_rename\Tug\3_61.wav
# [复制] data\Tug\20171221a-62\3_62.wav -> data_audio_rename\Tug\3_62.wav
# [复制] data\Tug\20171223b-63\3_63.wav -> data_audio_rename\Tug\3_63.wav
# [复制] data\Tug\20171225-64\3_64.wav -> data_audio_rename\Tug\3_64.wav
# [复制] data\Tug\20171226-65\3_65.wav -> data_audio_rename\Tug\3_65.wav
# [复制] data\Tug\20171227a-66\3_66.wav -> data_audio_rename\Tug\3_66.wav
# [复制] data\Tug\20171229a-67\3_67.wav -> data_audio_rename\Tug\3_67.wav
# [复制] data\Tug\20171229b-68\3_68.wav -> data_audio_rename\Tug\3_68.wav
# [复制] data\Tug\20171230a-69\3_69.wav -> data_audio_rename\Tug\3_69.wav
# [复制] data\Tug\20171231a-70\3_70.wav -> data_audio_rename\Tug\3_70.wav

# %% [markdown]
# # 根据切割后的音频片段，生成新的标注文件

# %%
ANNOT_PATH = Path(r"X:\数据集\DeepShip\data_preprocessing\annotation\DeepShip.csv")
# MEL_ROOT   = Path(r"X:\数据集\DeepShip\data_preprocessing\data_new_extract_2s_0%\mel_2s_0%")
MEL_ROOT   = Path(r"X:\数据集\DeepShip\data_preprocessing\data_new_extract_3s_0%\mel_3s_0%")

CLASS_ID_TO_NAME = {
    0: "Cargo",
    1: "Passengership",
    2: "Tanker",
    3: "Tug",
}

annotation = pd.read_csv(ANNOT_PATH)
extended_rows = []

for _, row in annotation.iterrows():
    cls_id = int(row["class_id"])
    cls_name = CLASS_ID_TO_NAME[cls_id]
    base_id = int(row["ID"])

    pattern = f"{cls_id}_{base_id}_*.npy"
    feature_paths = sorted((MEL_ROOT / cls_name).glob(pattern))
    if not feature_paths:
        print(f"缺少特征: {cls_name} ID {base_id}")
        continue

    for feat_path in feature_paths:
        seg_idx = int(feat_path.stem.split("_")[-1])
        entry = row.to_dict()
        entry["segment_id"] = f"{cls_id}_{base_id}_{seg_idx}"
        extended_rows.append(entry)

extended_df = pd.DataFrame(extended_rows)
extended_columns = [
    "ID", "class ID", "Recording ID", "Ship Name",
    "Date & Time", "Duration(sec)", "Distances(m)",
    "class_id", "folder_name",
    "segment_id", "prompt_en",
]

extended_df = extended_df.reindex(columns=extended_columns)
# out_path =  Path(r"X:\数据集\DeepShip\data_preprocessing\data_new_extract_2s_0%\mel_2s_0%\DeepShip_segments_mel.csv")
out_path =  Path(r"X:\数据集\DeepShip\data_preprocessing\data_new_extract_3s_0%\mel_3s_0%\DeepShip_segments_mel.csv")
extended_df.to_csv(out_path, index=False)
print(f"写出 {len(extended_df)} 条记录 -> {out_path}")
# Out:
# 缺少特征: Cargo ID 23
# 写出 56864 条记录 -> X:\数据集\DeepShip\data_preprocessing\data_new_extract_3s_0%\mel_3s_0%\DeepShip_segments_mel.csv

# %%
ANNOT_PATH = Path(r"X:\数据集\DeepShip\data_preprocessing\annotation\DeepShip.csv")
# MFCC_ROOT   = Path(r"X:\数据集\DeepShip\data_preprocessing\data_new_extract_2s_0%\mfcc_2s_0%")
MFCC_ROOT   = Path(r"X:\数据集\DeepShip\data_preprocessing\data_new_extract_3s_0%\mfcc_3s_0%")

CLASS_ID_TO_NAME = {
    0: "Cargo",
    1: "Passengership",
    2: "Tanker",
    3: "Tug",
}

annotation = pd.read_csv(ANNOT_PATH)
extended_rows = []

for _, row in annotation.iterrows():
    cls_id = int(row["class_id"])
    cls_name = CLASS_ID_TO_NAME[cls_id]
    base_id = int(row["ID"])

    pattern = f"{cls_id}_{base_id}_*.npy"
    feature_paths = sorted((MEL_ROOT / cls_name).glob(pattern))
    if not feature_paths:
        print(f"缺少特征: {cls_name} ID {base_id}")
        continue

    for feat_path in feature_paths:
        seg_idx = int(feat_path.stem.split("_")[-1])
        entry = row.to_dict()
        entry["segment_id"] = f"{cls_id}_{base_id}_{seg_idx}"
        extended_rows.append(entry)

extended_df = pd.DataFrame(extended_rows)
extended_columns = [
    "ID", "class ID", "Recording ID", "Ship Name",
    "Date & Time", "Duration(sec)", "Distances(m)",
    "class_id", "folder_name",
    "segment_id", "prompt_en",
]

extended_df = extended_df.reindex(columns=extended_columns)
# out_path =  Path(r"X:\数据集\DeepShip\data_preprocessing\data_new_extract_2s_0%\mfcc_2s_0%\DeepShip_segments_mfcc.csv")
out_path =  Path(r"X:\数据集\DeepShip\data_preprocessing\data_new_extract_3s_0%\mfcc_3s_0%\DeepShip_segments_mfcc.csv")
extended_df.to_csv(out_path, index=False)
print(f"写出 {len(extended_df)} 条记录 -> {out_path}")
# Out:
# 缺少特征: Cargo ID 23
# 写出 56864 条记录 -> X:\数据集\DeepShip\data_preprocessing\data_new_extract_3s_0%\mfcc_3s_0%\DeepShip_segments_mfcc.csv

# %%
ANNOT_PATH = Path(r"X:\数据集\DeepShip\data_preprocessing\annotation\DeepShip.csv")
# SEG_ROOT   = Path(r"X:\数据集\DeepShip\data_preprocessing\data_new_extract_2s_0%\mfcc_2s_0%")
# SEG_ROOT   = Path(r"X:\数据集\DeepShip\data_preprocessing\data_new_extract_3s_0%\mfcc_3s_0%")
SEG_ROOT   = Path(r"X:\数据集\DeepShip\data_preprocessing\data_new_extract_3s_0%_16kHz\mel_3s_0%_16kHz")

CLASS_ID_TO_NAME = {
    0: "Cargo",
    1: "Passengership",
    2: "Tanker",
    3: "Tug",
}

annotation = pd.read_csv(ANNOT_PATH)
extended_rows = []

for _, row in annotation.iterrows():
    cls_id = int(row["class_id"])
    cls_name = CLASS_ID_TO_NAME[cls_id]
    base_id = int(row["ID"])

    pattern = f"{cls_id}_{base_id}_*.npy"
    feature_paths = sorted((SEG_ROOT / cls_name).glob(pattern))
    if not feature_paths:
        print(f"缺少特征: {cls_name} ID {base_id}")
        continue

    for feat_path in feature_paths:
        seg_idx = int(feat_path.stem.split("_")[-1])
        entry = row.to_dict()
        entry["segment_id"] = f"{cls_id}_{base_id}_{seg_idx}"
        extended_rows.append(entry)

extended_df = pd.DataFrame(extended_rows)
extended_columns = [
    "ID", "class ID", "Recording ID", "Ship Name",
    "Date & Time", "Duration(sec)", "Distances(m)",
    "class_id", "folder_name",
    "segment_id", "prompt_en",
]

extended_df = extended_df.reindex(columns=extended_columns)
out_path =  Path(r"X:\数据集\DeepShip\data_preprocessing\annotation\DeepShip_segments_3s_0%_16kHz.csv")
extended_df.to_csv(out_path, index=False)
print(f"写出 {len(extended_df)} 条记录 -> {out_path}")
# Out:
# 缺少特征: Cargo ID 23
# 写出 56864 条记录 -> X:\数据集\DeepShip\data_preprocessing\annotation\DeepShip_segments_3s_0%_16kHz.csv
